# %%
import pandas as pd
from geopy import distance
from tqdm import tqdm
import gmplot
from matplotlib import pyplot as plt
from sklearn.cluster import DBSCAN
import numpy as np
import requests

# %%
filepath = "/home/yash/Documents/CB/location_data/"
filename = "original_points/User0.json"

# Less -> More accuracy
accuracy_threshold = 50

# In seconds
tdiff_threshold = 1200

# In metres
geodist_threshold = 50

visit_threshold = 300

# %%
# Read file into dataframe
df = pd.read_json(filepath+filename, orient='records')

# Drop useless columns
df.drop(['activity', 'altitude', 'verticalAccuracy', 'heading', 'velocity'], axis=1, inplace=True)

# Rename weirdly named columns
df.rename(index = int, columns = {'latitudeE7':'latitude',
                                  'longitudeE7': 'longitude',
                                  'timestampMs' : 'timestamp'}, inplace =True)

# Apply accuracy filter
df = df[df['accuracy'] <= accuracy_threshold]

# Apply the time range filter
df = df[df['timestamp'].dt.year==2018]

# Arrange the dataframe in ascending time order
df = df.reindex(index=df.index[::-1])
df['index'] = list(range(df.shape[0])) 
df.set_index('index', inplace=True)

# Initialise time difference and geodist columns
df['tdiff'] = 0
df['geodist'] = 0

# Lat and Long in the form 19045972, 73025802
# Convert to 19.045972, 73.025802
df['latitude'] = df['latitude'].apply(lambda x: x/10000000)
df['longitude'] = df['longitude'].apply(lambda x: x/10000000)
df['location'] = list(zip(df.latitude, df.longitude))

# Add additional date and time related columns
df['day'] = df['timestamp'].dt.weekday
df['week'] = df['timestamp'].dt.week
df['month'] = df['timestamp'].dt.month
df['year'] = df['timestamp'].dt.year

df
# Out:
#        accuracy   latitude  longitude               timestamp  tdiff  geodist  \
# index
# 0            50  19.053380  72.847517 2018-01-03 10:57:29.239      0        0
# 1            19  19.053036  72.847732 2018-01-03 10:57:45.000      0        0
# 2             4  19.052977  72.847690 2018-01-03 10:58:01.000      0        0
# 3             3  19.052977  72.847691 2018-01-03 10:58:17.000      0        0
# 4             3  19.052975  72.847690 2018-01-03 10:58:33.000      0        0
# 5             3  19.052863  72.847347 2018-01-03 10:59:14.000      0        0
# 6             4  19.053597  72.846182 2018-01-03 10:59:36.000      0        0
# 7            15  19.042293  72.840299 2018-01-03 11:01:41.000      0        0
# 8             8  19.040786  72.841125 2018-01-03 11:01:56.000      0        0
# 9            23  19.033604  72.838718 2018-01-03 11:05:58.000      0        0
# 10           28  19.033205  72.838990 2018-01-03 11:12:44.470      0        0
# 11           23  19.033204  72.838993 2018-01-03 11:13:11.861      0        0
# 12           20  19.033205  72.838990 2018-01-03 11:22:18.142      0        0
# 13           20  19.033205  72.838990 2018-01-03 11:27:21.311      0        0
# 14           25  19.033091  72.838848 2018-01-03 11:48:32.737      0        0
# 15           26  19.032684  72.838705 2018-01-03 12:03:56.790      0        0
# 16           26  19.032674  72.838674 2018-01-03 12:06:52.488      0        0
# 17           29  19.032718  72.838683 2018-01-03 12:08:31.221      0        0
# 18           30  19.039631  72.839398 2018-01-03 12:35:43.000      0        0
# 19           43  19.042406  72.840043 2018-01-03 12:36:48.000      0        0
# 32183  (19.0544645, 72.8521889)    4    18      5  2018
# 32184  (19.0544645, 72.8521889)    4    18      5  2018
# 32185  (19.0544645, 72.8521889)    4    18      5  2018
# 32186  (19.0544645, 72.8521889)    4    18      5  2018
# 32187  (19.0544645, 72.8521889)    4    18      5  2018
# 32188  (19.0544645, 72.8521889)    4    18      5  2018
#
# [32189 rows x 11 columns]

# %%
# Returns time difference between 2 timestamps in seconds
def timeDiff(t1, t2):
    return round(pd.Timedelta(t2 - t1).seconds)

def geoDist(l1, l2):
    return round(distance.vincenty(l1, l2).m )

# %%
# Generate two series objects from the timestamps in such a way that both can be subtracts(timeDiff)
# Combine the two series objects wuth the function tdiff

ts = df['timestamp']
ts1 = ts.shift(periods=1)[1:]
ts2 = ts[1:]

df['tdiff'] = ts1.astype(object).combine(ts2, func=timeDiff)
df['tdiff'][0] = 0

location = df['location']
location1 = location.shift(periods=1)[1:]
location2 = location[1:]

df['geodist'] = location1.astype(object).combine(location2, func=geoDist)
df['geodist'][0] = 0

df
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#        accuracy   latitude  longitude               timestamp tdiff geodist  \
# index
# 0            50  19.053380  72.847517 2018-01-03 10:57:29.239     0       0
# 1            19  19.053036  72.847732 2018-01-03 10:57:45.000    15      44
# 2             4  19.052977  72.847690 2018-01-03 10:58:01.000    16       8
# 3             3  19.052977  72.847691 2018-01-03 10:58:17.000    16       0
# 4             3  19.052975  72.847690 2018-01-03 10:58:33.000    16       0
# 5             3  19.052863  72.847347 2018-01-03 10:59:14.000    41      38
# 6             4  19.053597  72.846182 2018-01-03 10:59:36.000    22     147
# 7            15  19.042293  72.840299 2018-01-03 11:01:41.000   125    1396
# 8             8  19.040786  72.841125 2018-01-03 11:01:56.000    15     188
# 9            23  19.033604  72.838718 2018-01-03 11:05:58.000   242     834
# 10           28  19.033205  72.838990 2018-01-03 11:12:44.470   406      53
# 11           23  19.033204  72.838993 2018-01-03 11:13:11.861    27       0
# 12           20  19.033205  72.838990 2018-01-03 11:22:18.142   546       0
# 13           20  19.033205  72.838990 2018-01-03 11:27:21.311   303       0
# 14           25  19.033091  72.838848 2018-01-03 11:48:32.737  1271      20
# 15           26  19.032684  72.838705 2018-01-03 12:03:56.790   924      48
# 16           26  19.032674  72.838674 2018-01-03 12:06:52.488   175       3
# 17           29  19.032718  72.838683 2018-01-03 12:08:31.221    98       5
# 18           30  19.039631  72.839398 2018-01-03 12:35:43.000  1631     769
# 19           43  19.042406  72.840043 2018-01-03 12:36:48.000    65     315
# 20           50  19.055605  72.850849 2018-01-03 12:41:21.537   273    1852
# 21           26  19.054518  72.852385 2018-01-03 12:43:02.158   100     202
# 22           20  19.055118  72.852087 2018-01-03 12:45:27.283   145      74
# 23           20  19.055118  72.852087 2018-01-03 12:46:27.545    60       0
# 24           20  19.055118  72.852087 2018-01-03 12:48:41.725   134       0
# 25           50  19.055023  72.852120 2018-01-03 12:52:55.984   254      11
# 26           50  19.055043  72.852114 2018-01-03 12:54:57.094   121       2
# If it fits within tdiff and geodist bounds, consider the point to be a part of the staypoint

# Set the first entry to be the parent SP

df['visit_time'] = 0

parent = 0
visit_time = 0

for i in tqdm(df.index[1:]):
    
    # Check if the entry's tdiff and geodist fall within constraints
    
    # If yes, add its time to total time at that SP
    if (df['geodist'][i]<=geodist_threshold and df['tdiff'][i]<=tdiff_threshold):
        visit_time += df['tdiff'][i]
        df.drop(i, inplace=True)
    
    # If no, make the parent entry SP and set this to be the parent entry
    else:
        
        if visit_time < visit_threshold:
            df.drop(parent, inplace=True)
            
        else:
            # append parent to final df
            df['visit_time'][parent] = visit_time

        # Set new parent
        parent = i
        visit_time = 0

df
# Out:
#   0%|          | 1/32188 [00:00<1:14:16,  7.22it/s]/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 100%|██████████| 32188/32188 [01:46<00:00, 301.05it/s]
#        accuracy   latitude  longitude               timestamp  tdiff geodist  \
# index
# 10           28  19.033205  72.838990 2018-01-03 11:12:44.470    406      53
# 14           25  19.033091  72.838848 2018-01-03 11:48:32.737   1271      20
# 22           20  19.055118  72.852087 2018-01-03 12:45:27.283    145      74
# 33           20  19.055118  72.852087 2018-01-03 14:45:06.261   5604       0
# 67           27  19.136537  72.831541 2018-01-06 11:34:30.178     29     102
# 98            5  19.098726  72.845997 2018-01-10 09:03:26.000     15      66
# 252          24  19.097369  72.850002 2018-01-10 09:51:56.578     58      80
# 265          50  19.054599  72.852072 2018-01-10 10:25:34.945    405      63
# 320          26  19.054540  72.852506 2018-01-10 14:10:53.768    141      84
# 344          35  19.054768  72.852029 2018-01-10 20:37:02.385  18073      28
# 383          24  19.054929  72.852189 2018-01-11 01:52:40.379   1801      31
# 425          29  19.076820  72.834551 2018-01-13 11:00:13.591     57      68
# 487          25  19.054794  72.852241 2018-01-13 14:37:25.439   5285    1518
# 490          45  19.054759  72.852028 2018-01-13 18:11:51.482  11624      33
# 495          50  19.054848  72.851976 2018-01-13 19:50:05.668   3392       8
# 501          30  19.054781  72.852099 2018-01-14 02:42:57.537   1250      13
# 505          20  19.055114  72.852090 2018-01-14 06:57:15.414  14789      27
# 524          25  19.054750  72.852214 2018-01-14 08:53:35.153   2252       3
# 534          24  19.107265  72.836905 2018-01-16 01:35:01.035     58     175
# 714          27  19.054556  72.852337 2018-01-16 09:01:23.433     17      58
# 724          48  19.054979  72.852190 2018-01-16 11:26:26.978   6331       9
# 738          24  19.054570  72.852251 2018-01-16 14:27:45.306     63      53
# 742          24  19.054599  72.852281 2018-01-16 16:15:08.077   5843      16
# 745          26  19.054611  72.852253 2018-01-17 01:28:50.606  32347       2
# 749          25  19.054720  72.852245 2018-01-17 03:19:16.826   3086       8
# 761          20  19.107181  72.837210 2018-01-17 05:01:40.683   3600      55
# 893          26  19.054605  72.852277 2018-01-17 11:12:52.153     64     144
# 918          33  19.054858  72.852092 2018-01-17 12:21:18.470   1294      14
# 921          20  19.055114  72.852090 2018-01-17 12:56:43.523   1620      43
# 978          27  19.054717  72.852246 2018-01-17 16:10:15.397   1375       1
# 32126  (19.0544645, 72.8521889)    4    18      5  2018           0
#
# [764 rows x 12 columns]

# %%
df['index'] = list(range(df.shape[0])) 
df.set_index('index', inplace=True)

# Generate two series objects from the timestamps in such a way that both can be subtracts(timeDiff)
# Combine the two series objects with the function tdiff

ts = df['timestamp']
ts1 = ts.shift(periods=1)[1:]
ts2 = ts[1:]

df['tdiff'] = ts1.astype(object).combine(ts2, func=timeDiff)
df['tdiff'] = df['tdiff'] - df['visit_time'].shift(1)[1:]
df['tdiff'][0] = 0

location = df['location']
location1 = location.shift(periods=1)[1:]
location2 = location[1:]

df['geodist'] = location1.astype(object).combine(location2, func=geoDist)
df['geodist'][0] = 0

df
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        accuracy   latitude  longitude               timestamp  tdiff geodist  \
# index
# 0            28  19.033205  72.838990 2018-01-03 11:12:44.470      0       0
# 1            25  19.033091  72.838848 2018-01-03 11:48:32.737   1272      20
# 2            20  19.055118  72.852087 2018-01-03 12:45:27.283   2217    2808
# 3            20  19.055118  72.852087 2018-01-03 14:45:06.261   5607       0
# 4            27  19.136537  72.831541 2018-01-06 11:34:30.178  69247    9268
# 5             5  19.098726  72.845997 2018-01-10 09:03:26.000  76928    4453
# 6            24  19.097369  72.850002 2018-01-10 09:51:56.578     61     447
# 7            50  19.054599  72.852072 2018-01-10 10:25:34.945   1215    4739
# 8            26  19.054540  72.852506 2018-01-10 14:10:53.768   4479      46
# 9            35  19.054768  72.852029 2018-01-10 20:37:02.385  18085      56
# 10           24  19.054929  72.852189 2018-01-11 01:52:40.379   5262      25
# 11           29  19.076820  72.834551 2018-01-13 11:00:13.591  29885    3053
# 12           25  19.054794  72.852241 2018-01-13 14:37:25.439   6619    3068
# 13           45  19.054759  72.852028 2018-01-13 18:11:51.482  11885      23
# 14           50  19.054848  72.851976 2018-01-13 19:50:05.668   3394      11
# 15           30  19.054781  72.852099 2018-01-14 02:42:57.537  24402      15
# 16           20  19.055114  72.852090 2018-01-14 06:57:15.414  14790      37
# 17           25  19.054750  72.852214 2018-01-14 08:53:35.153   3883      42
# 18           24  19.107265  72.836905 2018-01-16 01:35:01.035  59438    6032
# 19           27  19.054556  72.852337 2018-01-16 09:01:23.433   2799    6056
# 20           48  19.054979  72.852190 2018-01-16 11:26:26.978   6335      49
# 21           24  19.054570  72.852251 2018-01-16 14:27:45.306   9296      46
# 22           24  19.054599  72.852281 2018-01-16 16:15:08.077   5844       4
# 23           26  19.054611  72.852253 2018-01-17 01:28:50.606  32348       3
# 24           25  19.054720  72.852245 2018-01-17 03:19:16.826   6004      12
# 25           20  19.107181  72.837210 2018-01-17 05:01:40.683   5136    6019
# 26           26  19.054605  72.852277 2018-01-17 11:12:52.153   1519    6032
# 27           33  19.054858  72.852092 2018-01-17 12:21:18.470   1306      34
# 28           20  19.055114  72.852090 2018-01-17 12:56:43.523   1622      28
# 29           27  19.054717  72.852246 2018-01-17 16:10:15.397   1400      47
# ...         ...        ...        ...                     ...    ...     ...
# 2              -1  Unknown
# 3               0  Unknown
# 4              -1  Unknown
# 5              -1  Unknown
# 6               0  Unknown
# 7              -1  Unknown
# 8               0  Unknown
# 9               0  Unknown
# 10              0  Unknown
# 11              0  Unknown
# 12             -1  Unknown
# 13              0  Unknown
# 14              0  Unknown
# 15              0  Unknown
# 16             -1  Unknown
# 17              0  Unknown
# 18              0  Unknown
# 19              0  Unknown
# 20              0  Unknown
# 21              0  Unknown
# 22              0  Unknown
# 23              0  Unknown
# 24              0  Unknown
# 25              0  Unknown
# 26              0  Unknown
# 27              0  Unknown
# 28              0  Unknown
# 29              0  Unknown
# ...           ...      ...
# 734             0  Unknown
# 735             0  Unknown
# 736             0  Unknown
# 737             0  Unknown
# 738             0  Unknown
# 739             0  Unknown
# 740             0  Unknown
# 741             0  Unknown
# 742             0  Unknown
# 743             0  Unknown
# 744             0  Unknown
# 745             0  Unknown
# 746             0  Unknown
# 747             0  Unknown
# 748             0  Unknown
# 749             0  Unknown
# 750             0  Unknown
# 751             0  Unknown
# 752             0  Unknown
# 753             0  Unknown
# 754             0  Unknown
# 755             0  Unknown
# 756             0  Unknown
# 757             0  Unknown
# 758             0  Unknown
# 759             0  Unknown
# 760             0  Unknown
# 761             0  Unknown
# 762             0  Unknown
# 763             0  Unknown
#
# [764 rows x 14 columns]

# %%
"""
df.to_csv(filepath+'stay_points/Lx2018SP.csv')

gmap = gmplot.GoogleMapPlotter(19.05, 72.8, 16)
gmap.scatter(df['latitude'], df['longitude'], 'black' , marker=True)
gmap.draw('CB2018SP.html')
del gmap
"""
# Out:
# "\ngmap = gmplot.GoogleMapPlotter(19.05, 72.8, 16)\ngmap.scatter(df['latitude'], df['longitude'], 'black' , marker=True)\ngmap.draw('CB2018SP.html')\ndel gmap\n"

# %%
# Form clusters
# Takes dataframe of staypoints as parameter and adds a column cluster_id to it
# Uses DBSCAN, param: min_smaples and epsilon
def form_clusters(df, index):
  coords = df.iloc[index].as_matrix(columns=['latitude', 'longitude'])
  
  kms_per_radian = 6371.0088
  epsilon = 0.03 / kms_per_radian
  db = DBSCAN(eps=epsilon, min_samples=2, algorithm='ball_tree', metric='haversine').fit(np.radians(coords))
  cluster_labels = db.labels_
  num_clusters = len(set(cluster_labels))
  
  df.loc[index,'cluster_id'] = cluster_labels
  
  print('Number of clusters: {}'.format(num_clusters))

# %%
df['cluster_id'] = 0
df['tag'] = "Unknown"

dic = {}

for year in df.year.drop_duplicates():
    
    for week in df[df['year']==year].week.drop_duplicates():
        
        temp = df.loc[ (df['year']==year) & (df['week']==week) ]
        form_clusters(df, temp.index)
        temp = df.loc[ (df['year']==year) & (df['week']==week) ]
        
        if temp.cluster_id.max() >= 1:
        
            # Create a df to reduce the clusters to centroids

            centroids = pd.DataFrame()
            centroids['cluster_id'] = list(range(temp.cluster_id.max()+1)) 
            centroids.set_index('cluster_id', inplace=True)
            centroids['latitude'] = 0.0
            centroids['longitude'] = 0.0
            centroids['week_visit_time'] = 0
            centroids['week_frequency'] = 0
            centroids['tag'] = "Unknown"

            for i in centroids.index:
                rows = temp[temp['cluster_id']==i]
                centroids['latitude'][i] = rows['latitude'].mean()
                centroids['longitude'][i] = rows['longitude'].mean()
                centroids['week_visit_time'][i] = rows['visit_time'].sum()
                centroids['week_frequency'][i] = rows.shape[0]

            print(centroids)
            
            home_id = centroids['week_visit_time'].idxmax()
            t = centroids.drop(home_id)
            work_id = t['week_visit_time'].idxmax()
            print(home_id, work_id)
            df.loc[(df['year']==year) & (df['week']==week) & (df['cluster_id']==home_id) , 'tag'] = 'Home'
            df.loc[(df['year']==year) & (df['week']==week) & (df['cluster_id']==work_id) , 'tag']= 'Work'
            
df['tag'].value_counts()
# Out:
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.033148  72.838919             2073               2
# 1           19.055118  72.852087             7287               2
# 1 0
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 2
# Number of clusters: 6
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.107226  72.837036            94478               8
# 1           19.054746  72.852201            50781              23
# 2           19.054610  72.851601            20438               7
# 3           19.015464  72.828173             1445               2
# 4           19.086206  72.888870             5000               2
# 0 1
# Number of clusters: 8
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054748  72.852132            34317              19
# 1           19.107224  72.837042            67470               6
# 2           19.108114  72.839013             2972               3
# 3           19.054550  72.851562            15475               6
# 4           19.106899  72.836874            27364               2
# 5           19.054065  72.850655            82206               9
# 6           19.069195  72.866577             4118               2
# 5 1
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054643  72.852210            12929               8
# 1           19.107241  72.837057            63457               4
# 2           19.055170  72.852116            34842               6
# 1 2
# Number of clusters: 5
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054652  72.851935             2644               2
# 1           19.107148  72.836966            49758               3
# 2           19.055058  72.852136            55643               6
# 3           19.054447  72.852502             2273               2
# 2 1
# Number of clusters: 5
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.055184  72.852148           157012              23
# 1           19.054657  72.852239            12595               6
# 2           19.012815  72.825158              970               2
# 3           19.107178  72.836979            70151               5
# 0 3
# Number of clusters: 7
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.055022  72.852093            71058              12
# 1           19.055455  72.851010            39959               8
# 2           19.054634  72.852246            48821              12
# 3           19.065363  72.858951              721               2
# 4           19.012720  72.825550             5656               5
# 5           19.107239  72.837087            67674               5
# 0 5
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054639  72.852164           182064              30
# 1           19.107212  72.837115            72800               9
# 0 1
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054690  72.852166           120130              25
# 1           19.107207  72.837108           123592              11
# 2           19.045290  73.082461            48811               2
# 1 0
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054749  72.852114           149080              46
# 1           19.107182  72.836989           115965              12
# 2           19.022509  72.856394             4772               2
# 0 1
# Number of clusters: 6
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.107359  72.837154           115999              14
# 1           19.054705  72.852090           113830              24
# 2           19.086460  72.889545             6619               4
# 3           19.110029  72.837517            10790               4
# 4           19.086271  72.888677             3865               2
# 0 1
# Number of clusters: 7
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054772  72.852115           239246              42
# 1           19.022230  72.855739            34975               6
# 2           19.086426  72.889464             4966               2
# 3           19.086698  72.889922             5322               2
# 4           19.022153  72.856304            14405               3
# 5           19.022358  72.855432            21835               2
# 0 1
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054698  72.852189           290293              42
# 1           19.107087  72.836876            78491               6
# 2           19.107192  72.837208            38043               3
# 0 1
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.107179  72.837028            91667               7
# 1           19.054665  72.852149           200621              37
# 1 0
# Number of clusters: 5
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054631  72.852174           171226              42
# 1           19.107147  72.837051            99702              13
# 2           19.110054  72.837600             5742               2
# 3           19.108375  72.838605             4787               2
# 0 1
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054634  72.852110            70542              19
# 1           19.107181  72.837114           130382              11
# 1 0
# Number of clusters: 3
#              latitude  longitude  week_visit_time  week_frequency
# cluster_id
# 0           19.054751  72.852060            48349              16
# 1           19.107123  72.837125            64151               6
# 1 0
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df['cluster_id'] = 0
df['tag'] = "Unknown"

dic = 0

for year in df.year.drop_duplicates():
    
    for week in df[df['year']==year].week.drop_duplicates():
        
        temp = df.loc[ (df['year']==year) & (df['week']==week) ]
        form_clusters(df, temp.index)
        temp = df.loc[ (df['year']==year) & (df['week']==week) ]
        
        if temp.cluster_id.max() >= 1:
        
            # Create a df to reduce the clusters to centroids

            centroids = pd.DataFrame()
            centroids['cluster_id'] = list(range(temp.cluster_id.max()+1)) 
            centroids.set_index('cluster_id', inplace=True)
            centroids['latitude'] = 0.0
            centroids['longitude'] = 0.0
            centroids['week_visit_time'] = 0
            centroids['week_frequency'] = 0
            centroids['tag'] = "Unknown"

            for i in centroids.index:
                rows = temp[temp['cluster_id']==i]
                lat = centroids['latitude'][i] = rows['latitude'].mean()
                long = centroids['longitude'][i] = rows['longitude'].mean()
                centroids['week_visit_time'][i] = rows['visit_time'].sum()
                centroids['week_frequency'][i] = rows.shape[0]
                
                dic+=1
                places = requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' + str(lat) + ',' + str(long) 
                       + '&rankby=distance'+'&key=AIzaSyBdqlVT2vWz9wu_olDovWYI561da6QtKyk').json()['results']

            
            
            
print(dic)            
#df['tag'].value_counts()
# Out:
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 2
# Number of clusters: 6
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 8
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 5
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 5
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 7
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 6
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 7
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 4
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 5
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Number of clusters: 3
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 63

# %%
requests.get('https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=19.054737,72.852247&radius=50&key=AIzaSyBdqlVT2vWz9wu_olDovWYI561da6QtKyk').json()['results']
# Out:
# [{'geometry': {'location': {'lat': 19.0759837, 'lng': 72.8776559},
#    'viewport': {'northeast': {'lat': 19.2716339, 'lng': 72.9864994},
#     'southwest': {'lat': 18.8928676, 'lng': 72.7758729}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#   'id': '2e66c82c2e8d7149bd7e026089ff5dedb8346bd5',
#   'name': 'Mumbai',
#   'photos': [{'height': 1360,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112673460654122926685/photos">Jaideep Chaudhary</a>'],
#     'photo_reference': 'CmRaAAAAMKLgWkkrGrm2z0MbzRfZLMnsTdDo5FO4Pl1vbixBnLXV_NJMc9DkpfCY5d--aZ0R5yBtW1c_mJsOw1ouzm1HG36E-6VpTuX5E_fM0Tt7xQhML16oS-NDeCg9H3jfKH8yEhBIf0-snZSjbdqYXD5CdwvoGhQsrkk3AoDFN9IwgUHFc_4pA_GZcg',
#     'width': 2048}],
#   'place_id': 'ChIJwe1EZjDG5zsRaYxkjY_tpF0',
#   'reference': 'CmRbAAAAEO64paVp2sljMyjY2aMsWMtxY6NpQb-ys1HrVTRE65pWgdbzREQgQLns_fWIfs98XT9CCPE5OppebbW4_nfOMPfNAFM5b2o02sXYAySPCW0c9BlCQn3mAB-yWOMpf0IiEhD62Q_8z5gpUp8PPbtxw3TzGhT7QQHnz2yofmTX731dKBo1ahGpNw',
#   'scope': 'GOOGLE',
#   'types': ['locality', 'political'],
#   'vicinity': 'Mumbai'},
#  {'geometry': {'location': {'lat': 19.0544008, 'lng': 72.8524098},
#    'viewport': {'northeast': {'lat': 19.0557497802915,
#      'lng': 72.85375878029151},
#     'southwest': {'lat': 19.05305181970849, 'lng': 72.8510608197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': '71cf6175982633349d7ed07f7fda78f3efd1e7cd',
#   'name': 'Indian Oil Complex',
#   'photos': [{'height': 3264,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117098878240190606820/photos">Ashok Sethi</a>'],
#     'photo_reference': 'CmRaAAAAcadRohfNtc5PxoRWbvqDCk7Yz197WYlletpO8Ung7KpvwCk79HrrV00IcJyq50cvJOXSpm6Lo09VEVaFH2DAMElQrNUOMgDrkztxR4f3q5mECr3VtMJOy_3gRHvnLu6JEhCMaNsOezj0s6Nc18u5teQdGhStJQVMBVIwUxVlDan6Uv2x3W1OQw',
#     'width': 2448}],
#   'place_id': 'ChIJk34qTN_I5zsRWr0SKbjcEKs',
#   'rating': 4.6,
#   'reference': 'CmRSAAAAJTm1ARNzanaAaqUBIwrcCpfdslG_7rFNCmsseGpmvc5khukVGh-N82GoDROpmo2j4txW3bPLV5pTR0y1feueaMYjQnNOYa51PusNO9WgXBplDaiRA04tzB1YlESML-X6EhB-a3xYraQ8Gmyd4skLY-b4GhSICXAchkCBahORI0KXYmp-_KhoYg',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'vicinity': 'Bandra Kurla Complex Road, E Block BKC, Bandra Kurla Complex, Bandra East, Mumbai'},
#  {'geometry': {'location': {'lat': 19.0546904, 'lng': 72.8522053},
#    'viewport': {'northeast': {'lat': 19.0560393802915,
#      'lng': 72.8535542802915},
#     'southwest': {'lat': 19.0533414197085, 'lng': 72.85085631970848}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': 'f464b239511e21d66d8ec9072e7e690382cb6ebf',
#   'name': "Unit Trust Of India Officer's Staff Quarter",
#   'place_id': 'ChIJ9QG9Wt_I5zsRoCl9r-7XFXo',
#   'rating': 3,
#   'reference': 'CmRRAAAAGYkuE6A1JlNZ5x0N3Eu9uLP6PN33A2GDi6I7He2jLnLar1e2bAyZRI4MDEMhlAvgWhYWGZ9X-tqUb9ZQqAILNsqpjegbasZeJkv9ynseNPTdzSK2GvpWoy0PLUZnl5enEhCgsVouQr_F-CKYL4bGHdMZGhTnF5UVFgyMuWz4p5FmkCHxmw8LHg',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'vicinity': 'R-2, Bandra Kurla Complex, Bandra East, Mumbai'},
#  {'geometry': {'location': {'lat': 19.0549506, 'lng': 72.852448},
#    'viewport': {'northeast': {'lat': 19.0562995802915,
#      'lng': 72.8537969802915},
#     'southwest': {'lat': 19.05360161970849, 'lng': 72.85109901970849}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': '526f86c655910f5bf61c274e7a36418b94167adb',
#   'name': "RBI Officers' Quarters",
#   'place_id': 'ChIJ03rMQd_I5zsRmWEyuDLKHQ8',
#   'rating': 4.6,
#   'reference': 'CmRRAAAAPlCb4bybdykWuKmYosnszIgXD0dPEDi8Ry9Rej72AveR6kP-ehTndALbfeTwQ2zthUBC5AuMHrXCYC0D0d6Cgfcq2waDLWsEKP2c9IY53V7PVQwoUWeMDMvVc2ow7zU2EhANYh3q-GAW0yRIStOOiY5lGhRYqW8E5ct-43v1jTpA0uJtPP3L5A',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'vicinity': 'E Block BKC, Bandra Kurla Complex, Bandra East, Mumbai'},
#  {'geometry': {'location': {'lat': 19.0544533, 'lng': 72.8519402},
#    'viewport': {'northeast': {'lat': 19.0558022802915,
#      'lng': 72.85328918029151},
#     'southwest': {'lat': 19.05310431970849, 'lng': 72.8505912197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': '944d3a83f089cca3ccf3f5b53a992c33262de43d',
#   'name': 'Central Excise Residential Complex',
#   'place_id': 'ChIJWRPoUN_I5zsRlwBD1Zp948E',
#   'rating': 3,
#   'reference': 'CmRSAAAArOaDZIef9P-7DuxcaE2H9VezgZTCOf5FNSOCojIf_KD-2nnPHukqNxfu79KjjAockiv3G-bltKdS9KUBvpLijtFbYHCuuJ3unOsFg_0yBk9uQKlYdVfWYxM7qbuM7lO4EhA51XRYYJ47jfCzRvUmwwxyGhSt3iLBcNsBsfaMcjOMk9dvht27sQ',
#   'scope': 'GOOGLE',
#   'types': ['finance', 'point_of_interest', 'establishment'],
#   'vicinity': 'BKC, Mumbai, Maharashtra'},
#  {'geometry': {'location': {'lat': 19.0551106, 'lng': 72.8520235},
#    'viewport': {'northeast': {'lat': 19.0564595802915,
#      'lng': 72.8533724802915},
#     'southwest': {'lat': 19.0537616197085, 'lng': 72.85067451970849}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png',
#   'id': '1d51dddf7eb22958fca3f21fc803bbbcdaac1397',
#   'name': 'United Bank of India',
#   'opening_hours': {'open_now': True, 'weekday_text': []},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110461806410806062079/photos">Alok Kumar</a>'],
#     'photo_reference': 'CmRaAAAA1nyTuXm8Fe7pxuC5jqOJ4LeZWDdBHocQ8rwfLog0PcHavKr--z9jQIRp5la9cEkequCdA4UXDpuccNhoL5WqgaN8Lbdi6SnSYP9m0pluoTvnLrt2UhA4hek8Cp2L2ZSKEhD24sNHCsjyr-U-IjbAkD0oGhRjHzv5WaArf7vIh5QSbwso8ciFiw',
#     'width': 4000}],
#   'place_id': 'ChIJOS9GXN_I5zsR49N0iA1ZugE',
#   'rating': 4,
#   'reference': 'CmRRAAAAsxyEPVYX67GS28vfFf-_ivTQmXu_vRTBdX0aY4Ww_LEBXwS1WzXigiDxrKLvy9FNNzY58DOvt9p5FlIDKpc0iDbxlSybyfpjrtpdJN1H1f86Gcrl_pJszKzB20qmTE2ZEhAPd8EVayrmoUpKWTzz4pe0GhTrT8B_Vt12qBMG7MrkkBH2SCXLYA',
#   'scope': 'GOOGLE',
#   'types': ['bank', 'finance', 'point_of_interest', 'establishment'],
#   'vicinity': 'C-14,C-15, MMRDA Building, E Block BKC, Bandra Kurla Complex, Bandra East, Mumbai'},
#  {'geometry': {'location': {'lat': 19.0548365, 'lng': 72.8517966},
#    'viewport': {'northeast': {'lat': 19.05618548029151,
#      'lng': 72.85314558029151},
#     'southwest': {'lat': 19.0534875197085, 'lng': 72.85044761970849}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': 'cf49f57bdfe8dbf0c4ed4a0c7adfca22a1fd1525',
#   'name': 'DMRC Mumbai office',
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103730288413906747396/photos">Mangesh Mandke</a>'],
#     'photo_reference': 'CmRaAAAAqIKAQDwbAeZYcFN36l8Ju6gEe9Bx3vEqWvxGMRgcBeDd8wW7HHzI-NO27S3R1c4BDaKI8SvWcdaYAv1fdWh2y0V7Ua6i8HKEL_honqSPEqjemopnqxIxRCOX_qQs7SunEhDyUfX8HIjGcrYh7wjJ10LzGhRyFmi37tBCwRpSWw9_G4DSNOVQVQ',
#     'width': 4608}],
#   'place_id': 'ChIJhWwRWd_I5zsRAHME0bhFobY',
#   'rating': 3.7,
#   'reference': 'CmRSAAAAIXQfa5hW11JDN2OigjKbcd9zWelOX563Ov1tkop5VIB9UTt6CI1QSmqDBNiYGiuoaIPv_VYymtcyH8kBNNbbCxYb1ccD6ZWSgvNJ1Eg5QL8tg_hVim5l5B6jOOamVFOFEhD1CT1AgqQtxVAN9V5GiHvFGhRc3FGOblbUItEMOmBnqAbQETJVNQ',
#   'scope': 'GOOGLE',
#   'types': ['point_of_interest', 'establishment'],
#   'vicinity': '8th floor, E Block BKC, Bandra Kurla Complex, Bandra East, Mumbai'},
#  {'geometry': {'location': {'lat': 19.0543264, 'lng': 72.8524941},
#    'viewport': {'northeast': {'lat': 19.0556873802915,
#      'lng': 72.8538210302915},
#     'southwest': {'lat': 19.0529894197085, 'lng': 72.85112306970849}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#   'id': 'ac9c5dfa7ac7db21b36a347edd714b99e50793e7',
#   'name': 'Indian Oil Residential Building',
#   'place_id': 'ChIJsTGNTt_I5zsRIvQkomzyq18',
#   'reference': 'CmRbAAAALqX22EIvIK_1o2QA_4EP-AyycUFoe39jmPkiDuRKvIz7kaVCST8-MPYYRxoCLF1r7DcDyldmG4ebLwV8HGeYg0N4TIqyHJ5OnWV7euw2WjmwvCqgH-op8UDz-AuuDsUIEhCSl7FqhZKReoSSDyW84UxPGhSGr-UC_-10bYTjvPJXg2ana3dqKw',
#   'scope': 'GOOGLE',
#   'types': ['premise', 'point_of_interest', 'establishment'],
#   'vicinity': 'E Block BKC'},
#  {'geometry': {'location': {'lat': 19.0562207, 'lng': 72.85376339999999},
#    'viewport': {'northeast': {'lat': 19.059816, 'lng': 72.85714399999999},
#     'southwest': {'lat': 19.0531534, 'lng': 72.8509426}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#   'id': 'fa61f2f6ca812fc049d293916850d00fe1abadbe',
#   'name': 'E Block BKC',
#   'place_id': 'ChIJN9iEBt_I5zsR6D_lOvgqmYA',
#   'reference': 'CmRbAAAAvYLTH0EQ95-c43Cd4OdWpQpDrBaiAbud62YU7VVjDb0vOp39XVStlFK29pH7kx34-PPazJfVi0WtLQgtR4lyFk6f1kr3h1_DukzTIpmuOMCMKCdblF2XTfxqFyDPcVFJEhCBe3B9GBbGZLpGOg84HbR0GhTYMdOtJPzynPs1ZOsFz8bx6XRoJA',
#   'scope': 'GOOGLE',
#   'types': ['sublocality_level_3', 'sublocality', 'political'],
#   'vicinity': 'E Block BKC'}]
